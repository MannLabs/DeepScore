# %% [markdown]
# # Get Data
# Download the data from here:
#     https://datashare.biochem.mpg.de/s/3U2qb7EonBErttl
#
#     File to download:
#     thermo_HeLa.ms_data.hdf
#
# This is a basic hdf file generated with AlphaPept and will contain all necessary Output from an AlphaPept search.
# You will need to have alphapept installed (`!pip install alphapept`)

# %% [markdown]
# ## Explore the data

# %%
import alphapept.io

file_path = 'thermo_HeLa.ms_data.hdf'

ms_file = alphapept.io.MS_Data_File(file_path)

df = ms_file.read(dataset_name='second_search')

df.head()
# Out:
#    charge  db_idx   delta_m  delta_m_ppm  feature_idx  fragment_ion_idx  \
# 0     1.0      71 -0.000870    -3.751918        71983                 0
# 1     1.0      97 -0.001274    -6.516437       141318                13
# 2     1.0      97 -0.001627    -8.277261       141318                33
# 3     1.0     156 -0.000012    -0.045978       160855                53
# 4     1.0     157  0.000107     0.472260       160855                77
#
#    fragments_int_ratio  fragments_int_sum  fragments_matched_int_ratio  \
# 0         8.614146e+04           28573100                     0.039192
# 1         1.082959e+05           41038639                     0.052778
# 2         9.863660e+04           38998363                     0.050585
# 3         1.381110e+06          133365374                     0.248540
# 4         1.000270e+06          133365374                     0.150004
#
#    fragments_matched_int_sum  ...  prec_offset_raw_ppm        precursor  \
# ...
